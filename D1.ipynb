# %% [markdown]
# # day 1d

# %%
7*7
# Out:
# 49

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [
     {
         "name": "Earl Grey Cloud",
         "category": "E-commerce"
     },
    {
         "name": "Mint Medly Cloud",
         "category": "Sales"
     },
    {
         "name": "Green Cloud",
         "category": "Service"
     },
    ]
)

# %%
df
# Out:
#      category              name
# 0  E-commerce   Earl Grey Cloud
# 1       Sales  Mint Medly Cloud
# 2     Service       Green Cloud

# %% [markdown]
# ##Exercise
# Read Data

# %%
df = pd.read_csv("movie_history_for_user.csv")

# %%
df
# Out:
#      adult  vote_average  vote_count  popularity  release_year  is_action  \
# 0        0           6.8        3838  220.680675          2017          0
# 1        0           6.0         339  146.329357          2017          0
# 2        0           7.5         596  113.730475          2017          1
# 3        0           7.1        2686   82.304103          2017          1
# 4        0           7.3        3631   82.303675          2014          1
# 5        0           7.5        4602   67.713878          2017          1
# 6        0           5.2         996   55.476211          2017          1
# 7        0           6.3         607   51.655521          2017          1
# 8        0           6.1        2177   48.943499          2017          1
# 9        0           6.9        4668   43.621405          2014          1
# 10       0           7.2        8380   41.354905          2015          1
# 11       0           6.2        1220   41.212696          2017          0
# ...

# %%
df.dtypes
# Out:
# adult             int64
# vote_average    float64
# vote_count        int64
# popularity      float64
# release_year      int64
# is_action         int64
# is_drama          int64
# is_comedy         int64
# is_scifi          int64
# watched           int64
# dtype: object

# %%
df.columns
# Out:
# Index(['adult', 'vote_average', 'vote_count', 'popularity', 'release_year',
#        'is_action', 'is_drama', 'is_comedy', 'is_scifi', 'watched'],
#       dtype='object')

# %%
fields = [
'vote_average', 'vote_count', 'watched'
]

# %%
df[fields]
# Out:
#      vote_average  vote_count  watched
# 0             6.8        3838        0
# 1             6.0         339        0
# 2             7.5         596        0
# 3             7.1        2686        0
# 4             7.3        3631        1
# 5             7.5        4602        0
# 6             5.2         996        0
# 7             6.3         607        0
# 8             6.1        2177        0
# 9             6.9        4668        1
# 10            7.2        8380        0
# 11            6.2        1220        0
# 12            6.5        1604        1
# 13            7.8        8223        1
# 14            6.8        2850        0
# 15            5.8        1467        0
# 16            6.5        7733        0
# 17            7.4        6059        1
# 18            6.0          47        0
# 19            7.6        2813        0
# 20            6.8        3838        0
# 21            6.0         339        0
# 22            7.5         596        0
# ...

# %%
df.tail()
# Out:
#      adult  vote_average  vote_count  popularity  release_year  is_action  \
# 975      0           5.8        1467   38.280206          2017          0
# 976      0           6.5        7733   37.198215          2015          1
# 977      0           7.4        6059   34.303853          2003          1
# 978      0           6.0          47   33.620069          2017          1
# 979      0           7.6        2813   32.718841          2017          1
#
#      is_drama  is_comedy  is_scifi  watched
# 975         0          0         1        0
# 976         0          0         1        0
# 977         0          0         0        1
# 978         1          0         1        0
# 979         0          1         1        0

# %%
df.tail()[['watched']]
# Out:
#      watched
# 975        0
# 976        0
# 977        1
# 978        0
# 979        0

# %%
df['popularity']
# Out:
# 0      220.680675
# 1      146.329357
# 2      113.730475
# 3       82.304103
# 4       82.303675
# 5       67.713878
# 6       55.476211
# 7       51.655521
# 8       48.943499
# 9       43.621405
# 10      41.354905
# 11      41.212696
# 12      41.140038
# 13      39.437367
# 14      39.014829
# 15      38.280206
# 16      37.198215
# 17      34.303853
# 18      33.620069
# 19      32.718841
# 20     220.680675
# 21     146.329357
# 22     113.730475
# 23      82.304103
# 24      82.303675
# 25      67.713878
# 26      55.476211
# 27      51.655521
# 28      48.943499
# 29      43.621405
#           ...
# 950     41.354905
# 951     41.212696
# 952     41.140038
# 953     39.437367
# 954     39.014829
# 955     38.280206
# 956     37.198215
# 957     34.303853
# 958     33.620069
# 959     32.718841
# 960    220.680675
# 961    146.329357
# 962    113.730475
# 963     82.304103
# 964     82.303675
# 965     67.713878
# 966     55.476211
# 967     51.655521
# 968     48.943499
# ...

# %%
type (df['popularity'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##EXCRESISE 25 rows vote_count, watched, release_year

# %%
df.head(25)[['vote_count', 'watched', 'release_year']]
# Out:
#     vote_count  watched  release_year
# 0         3838        0          2017
# 1          339        0          2017
# 2          596        0          2017
# 3         2686        0          2017
# 4         3631        1          2014
# 5         4602        0          2017
# 6          996        0          2017
# 7          607        0          2017
# 8         2177        0          2017
# 9         4668        1          2014
# 10        8380        0          2015
# 11        1220        0          2017
# 12        1604        1          2017
# 13        8223        1          2014
# 14        2850        0          2017
# 15        1467        0          2017
# 16        7733        0          2015
# 17        6059        1          2003
# 18          47        0          2017
# 19        2813        0          2017
# 20        3838        0          2017
# 21         339        0          2017
# 22         596        0          2017
# 23        2686        0          2017
# ...

# %%
df.head(25)['vote_count'].sum()
# Out:
# 75626

# %%
df['vote_count'].head(25).sum()
# Out:
# 75626

# %%
df['vote_count'][:25].sum()
# Out:
# 75626

# %%
df[:25]['vote_count'].sum()
# Out:
# 75626

# %% [markdown]
# ##excerise avg pop of last 88 movies

# %%
df['popularity'].tail(88).median()
# Out:
# 41.2838005

# %%
df['popularity'].tail(88).mean()
# Out:
# 62.04400784090908

# %%
df['popularity'][-88:].mean()
# Out:
# 62.04400784090908

# %%
df.describe()
# Out:
#        adult  vote_average   vote_count  popularity  release_year   is_action  \
# count  980.0    980.000000   980.000000  980.000000    980.000000  980.000000
# mean     0.0      6.725000  3226.800000   64.551991   2015.650000    0.800000
# std      0.0      0.689464  2580.334836   46.007305      3.120487    0.400204
# min      0.0      5.200000    47.000000   32.718841   2003.000000    0.000000
# 25%      0.0      6.175000  1164.000000   38.831173   2015.000000    1.000000
# 50%      0.0      6.800000  2749.500000   42.488155   2017.000000    1.000000
# 75%      0.0      7.325000  4618.500000   71.361327   2017.000000    1.000000
# max      0.0      7.800000  8380.000000  220.680675   2017.000000    1.000000
#
#          is_drama   is_comedy    is_scifi     watched
# count  980.000000  980.000000  980.000000  980.000000
# mean     0.150000    0.150000    0.550000    0.250000
# std      0.357254    0.357254    0.497748    0.433234
# ...

# %%
df = pd.read_csv("Boston_Housing.csv")

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df[
    'CRIM'
].max()
# Out:
# 88.9762

# %%
df.where(df['CRIM']== 0.00632).dropna()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09  1.0  296.0     15.3
#
#        B  LSTAT  MEDV
# 0  396.9   4.98  24.0

# %%
df.where(df['CRIM']== 88.9762).dropna()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 380  88.9762  0.0   18.1   0.0  0.671  6.968  91.9  1.4165  24.0  666.0
#
#      PTRATIO      B  LSTAT  MEDV
# 380     20.2  396.9  17.21  10.4

# %%
df.where(df['CRIM']== df[
    'CRIM'
].max()).dropna()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 380  88.9762  0.0   18.1   0.0  0.671  6.968  91.9  1.4165  24.0  666.0
#
#      PTRATIO      B  LSTAT  MEDV
# 380     20.2  396.9  17.21  10.4

# %%
df.where(df['CRIM'] > 50).where(df['AGE'] > 50).dropna()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 380  88.9762  0.0   18.1   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 405  67.9208  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 410  51.1358  0.0   18.1   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 418  73.5341  0.0   18.1   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
#
#      PTRATIO       B  LSTAT  MEDV
# 380     20.2  396.90  17.21  10.4
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 418     20.2   16.45  20.62   8.8

# %% [markdown]
# Average dollar amount for products that either CPU or Maintenace
